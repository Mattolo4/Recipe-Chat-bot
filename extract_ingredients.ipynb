# %%
import pandas as pd
import numpy as np
from collections import Counter
import re
from preprocessing import *

# %%
df_all = load_data("RAW_recipes.csv")
df_food = filter_tags(df_all,["beverages"])
df_food.reset_index(drop=True, inplace=True)

# %%
ingredients = df_food["ingredients"]#.iloc[0:1000]
all_ingredients = np.concatenate(ingredients)
all_ingredients_counter = Counter(all_ingredients)

# %%
all_ingredients_counter
# Out:
# Counter({'salt': 85411,
#          'butter': 54913,
#          'sugar': 42143,
#          'onion': 39055,
#          'eggs': 33686,
#          'water': 33168,
#          'olive oil': 32819,
#          'flour': 26259,
#          'garlic cloves': 25739,
#          'milk': 24363,
#          'pepper': 22300,
#          'brown sugar': 18383,
#          'garlic': 18083,
#          'all-purpose flour': 17654,
#          'baking powder': 17500,
#          'egg': 17283,
#          'salt and pepper': 15408,
#          'parmesan cheese': 14807,
#          'baking soda': 14078,
#          'vegetable oil': 13909,
#          'lemon juice': 13573,
#          'black pepper': 13079,
#          'vanilla': 12944,
#          'cinnamon': 12062,
#          'tomatoes': 11929,
#          'sour cream': 11776,
#          'garlic powder': 10876,
#          'oil': 9923,
#          'onions': 9870,
#          'cream cheese': 9816,
#          'vanilla extract': 9772,
#          'garlic clove': 9772,
#          'celery': 9498,
#          'honey': 9144,
#          'cheddar cheese': 8969,
#          'unsalted butter': 8924,
#          'soy sauce': 8854,
#          'mayonnaise': 8736,
#          'paprika': 7977,
#          'chicken broth': 7962,
#          'worcestershire sauce': 7752,
#          'extra virgin olive oil': 7703,
#          'fresh parsley': 7646,
#          'cornstarch': 7450,
#          'fresh ground black pepper': 7146,
#          'parsley': 6984,
#          'chili powder': 6964,
#          'carrots': 6953,
#          'bacon': 6948,
#          'carrot': 6692,
#          'ground cinnamon': 6525,
#          'potatoes': 6507,
#          'lemon': 6293,
#          'cayenne pepper': 6249,
#          'ground cumin': 6160,
#          'granulated sugar': 6014,
#          'nutmeg': 6008,
#          'ground beef': 5824,
#          'green onions': 5813,
#          'red onion': 5775,
#          'walnuts': 5752,
#          'pecans': 5740,
#          'dijon mustard': 5598,
#          'green onion': 5584,
#          'kosher salt': 5547,
#          'powdered sugar': 5256,
#          'margarine': 5075,
#          'heavy cream': 5031,
#          'fresh lemon juice': 5004,
#          'mozzarella cheese': 4980,
#          'dried oregano': 4881,
#          'zucchini': 4587,
#          'raisins': 4457,
#          'red bell pepper': 4447,
#          'tomato sauce': 4402,
#          'fresh cilantro': 4356,
#          'chicken stock': 4351,
#          'tomato paste': 4332,
#          'canola oil': 4313,
#          'green pepper': 4301,
#          'cumin': 4228,
#          'oregano': 4184,
#          'fresh ginger': 4079,
#          'boneless skinless chicken breasts': 3994,
#          'ground black pepper': 3927,
#          'ketchup': 3899,
#          'balsamic vinegar': 3843,
#          'buttermilk': 3801,
#          'cilantro': 3735,
#          'juice of': 3710,
#          'fresh basil': 3629,
#          'onion powder': 3594,
#          'orange juice': 3579,
#          'ground ginger': 3566,
#          'dried thyme': 3528,
#          'ginger': 3515,
#          'diced tomatoes': 3462,
#          'vinegar': 3390,
#          'green bell pepper': 3284,
#          'lime juice': 3264,
#          'dried basil': 3250,
#          'bay leaf': 3246,
#          'egg whites': 3240,
#          'red wine vinegar': 3220,
#          'fresh ground pepper': 3213,
#          'white sugar': 3122,
#          'salt & freshly ground black pepper': 3121,
#          'sea salt': 3105,
#          'dry white wine': 3097,
#          "confectioners' sugar": 3095,
#          'whole wheat flour': 3052,
#          'whipping cream': 3041,
#          'light brown sugar': 2993,
#          'sesame oil': 2988,
#          'thyme': 2978,
#          'curry powder': 2958,
#          'crushed red pepper flakes': 2934,
#          'white wine': 2841,
#          'dry mustard': 2839,
#          'white pepper': 2827,
#          'chicken breasts': 2793,
#          'ground nutmeg': 2774,
#          'breadcrumbs': 2772,
#          'shortening': 2743,
#          'basil': 2724,
#          'mushrooms': 2717,
#          'cheese': 2712,
#          'salsa': 2703,
#          'garlic salt': 2636,
#          'egg yolks': 2602,
#          'red pepper flakes': 2602,
#          'semi-sweet chocolate chips': 2579,
#          'lean ground beef': 2560,
#          'cider vinegar': 2535,
#          'bay leaves': 2531,
#          'feta cheese': 2509,
#          'bananas': 2508,
#          'sharp cheddar cheese': 2483,
#          'black beans': 2468,
#          'scallions': 2424,
#          'monterey jack cheese': 2411,
#          'nuts': 2409,
#          'boiling water': 2394,
#          'peanut butter': 2304,
#          'yellow onion': 2296,
#          'seasoning salt': 2260,
#          'red pepper': 2251,
#          'chocolate chips': 2216,
#          'ground cloves': 2212,
#          'shallots': 2197,
#          'white vinegar': 2182,
#          'fresh thyme': 2180,
#          'salt & pepper': 2156,
#          'apples': 2141,
#          'cream of mushroom soup': 2138,
#          'tabasco sauce': 2133,
#          'sesame seeds': 2129,
#          'cucumber': 2123,
#          'chicken': 2115,
#          'hot sauce': 2102,
#          'beef broth': 2090,
#          'cooking spray': 2090,
#          'half-and-half': 2086,
#          'fresh mushrooms': 2079,
#          'shallot': 2066,
#          'evaporated milk': 2064,
#          'lime': 2064,
#          'fresh lime juice': 2063,
#          'swiss cheese': 2043,
#          'ground coriander': 2036,
#          'warm water': 2027,
#          'mushroom': 2020,
#          'italian seasoning': 1988,
#          'black olives': 1981,
#          'lemon zest': 1973,
#          'cooked chicken': 1931,
#          'almond extract': 1918,
#          'cold water': 1909,
#          'maple syrup': 1904,
#          'bread': 1903,
#          'shrimp': 1903,
#          'cream': 1901,
#          'sliced mushrooms': 1899,
#          'celery ribs': 1896,
#          'avocado': 1867,
#          'skim milk': 1863,
#          'turmeric': 1853,
#          'cayenne': 1847,
#          'cabbage': 1842,
#          'green chilies': 1808,
#          'whole milk': 1797,
#          'fresh rosemary': 1795,
#          'chives': 1756,
#          'boneless skinless chicken breast halves': 1753,
#          'lettuce': 1733,
#          'flour tortillas': 1725,
#          'molasses': 1720,
#          'lemons': 1713,
#          'sweetened condensed milk': 1700,
#          'dark brown sugar': 1697,
#          'plain yogurt': 1694,
#          'zest of': 1693,
#          'cocoa': 1684,
#          'hot water': 1666,
#          'almonds': 1661,
#          'egg white': 1659,
#          'pine nuts': 1654,
#          'cherry tomatoes': 1647,
#          'ham': 1642,
#          'peanut oil': 1626,
#          'capers': 1621,
#          'cooked rice': 1586,
#          'active dry yeast': 1581,
#          'frozen peas': 1575,
#          'orange zest': 1564,
#          'barbecue sauce': 1546,
#          'corn': 1532,
#          'cream of chicken soup': 1531,
#          'green beans': 1528,
#          'allspice': 1525,
#          'scallion': 1524,
#          'cornmeal': 1521,
#          'rice vinegar': 1519,
#          'potato': 1515,
#          'rolled oats': 1513,
#          'broccoli': 1505,
#          'bell pepper': 1505,
#          'fresh dill': 1501,
#          'coconut milk': 1496,
#          'coconut': 1481,
#          'red wine': 1478,
#          'sweet potatoes': 1476,
#          'crushed pineapple': 1475,
#          'apple': 1474,
#          'banana': 1459,
#          'rice': 1456,
#          'ricotta cheese': 1454,
#          'rosemary': 1430,
#          'white wine vinegar': 1422,
#          'fresh chives': 1408,
#          'red potatoes': 1400,
#          'vegetable broth': 1388,
#          'cooking oil': 1382,
#          'cocoa powder': 1367,
#          'apple cider vinegar': 1365,
#          'orange': 1361,
#          'gingerroot': 1360,
#          'egg yolk': 1345,
#          'plain flour': 1336,
#          'pure vanilla extract': 1330,
#          'beer': 1329,
#          'jalapeno pepper': 1325,
#          'dried cranberries': 1319,
#          'cool whip': 1313,
#          'white onion': 1311,
#          'mustard': 1306,
#          'chickpeas': 1295,
#          'spinach': 1293,
#          'sweet onion': 1285,
#          'dried parsley': 1272,
#          'fish sauce': 1266,
#          'vegetable stock': 1256,
#          'bread flour': 1253,
#          'slivered almonds': 1251,
#          'flat leaf parsley': 1242,
#          'yeast': 1240,
#          'icing sugar': 1236,
#          'boneless skinless chicken breast': 1236,
#          'ground allspice': 1228,
#          'fresh spinach': 1211,
#          'hot pepper sauce': 1211,
#          'blue cheese': 1194,
#          'sliced almonds': 1187,
#          'prepared mustard': 1178,
#          'plum tomatoes': 1177,
#          'applesauce': 1174,
#          'dry sherry': 1174,
#          'caster sugar': 1172,
#          'low sodium chicken broth': 1166,
#          'frozen chopped spinach': 1165,
#          'dried rosemary': 1154,
#          'light corn syrup': 1152,
#          'hard-boiled eggs': 1150,
#          'crushed tomatoes': 1146,
#          'of fresh mint': 1144,
#          'blueberries': 1130,
#          'jalapeno': 1123,
#          'white bread': 1094,
#          'red onions': 1093,
#          'clove': 1092,
#          'spaghetti': 1086,
#          'ground pepper': 1076,
#          'cream of tartar': 1069,
#          'coarse salt': 1066,
#          'pasta': 1061,
#          'coriander': 1060,
#          'cauliflower': 1058,
#          'pork tenderloin': 1044,
#          'asparagus': 1038,
#          'french bread': 1037,
#          'heavy whipping cream': 1027,
#          'kidney beans': 1025,
#          'unsweetened cocoa powder': 1025,
#          'strawberries': 1025,
#          'pork chops': 1024,
#          'salmon fillets': 1024,
#          'red bell peppers': 1013,
#          'elbow macaroni': 1007,
#          'spaghetti sauce': 1001,
#          'romaine lettuce': 991,
#          'dry breadcrumbs': 990,
#          'beef stock': 989,
#          'celery seed': 985,
#          'avocados': 978,
#          'ground turkey': 971,
#          'corn tortillas': 971,
#          'basil leaves': 966,
#          'fresh oregano': 960,
#          'fresh garlic': 950,
#          'dry red wine': 947,
#          'leeks': 945,
#          'ground red pepper': 942,
#          'chili sauce': 942,
#          'fresh strawberries': 942,
#          'baby spinach': 938,
#          'peanuts': 936,
#          'pumpkin': 936,
#          'baby carrots': 922,
#          'oatmeal': 907,
#          'graham cracker crumbs': 902,
#          'limes': 901,
#          'yellow cake mix': 898,
#          'salt and black pepper': 898,
#          'green peppers': 896,
#          'ground pork': 895,
#          'frozen corn': 888,
#          'cucumbers': 884,
#          'whipped cream': 882,
#          'cottage cheese': 871,
#          'velveeta cheese': 869,
#          'stewed tomatoes': 868,
#          'eggplant': 863,
#          'creamy peanut butter': 862,
#          'taco seasoning': 861,
#          'hoisin sauce': 859,
#          'sherry wine': 855,
#          'low sodium soy sauce': 852,
#          'tortilla chips': 851,
#          'jalapeno peppers': 847,
#          'russet potatoes': 846,
#          'peaches': 844,
#          'splenda sugar substitute': 843,
#          'flaked coconut': 843,
#          'strawberry': 842,
#          'cumin seed': 840,
#          'cake flour': 838,
#          'semisweet chocolate': 837,
#          'roma tomatoes': 828,
#          'butternut squash': 825,
#          'orange rind': 824,
#          'cooked ham': 819,
#          'oats': 813,
#          'cracked black pepper': 810,
#          'chopped tomatoes': 809,
#          'broccoli florets': 808,
#          'frozen spinach': 792,
#          'fresh coarse ground black pepper': 789,
#          'garam masala': 789,
#          'leek': 783,
#          'boneless chicken breasts': 782,
#          'dates': 778,
#          'jalapenos': 776,
#          'yellow cornmeal': 776,
#          'celery salt': 775,
#          'apple juice': 773,
#          'cinnamon stick': 773,
#          'baking potatoes': 761,
#          'fresh basil leaf': 761,
#          'ground cardamom': 760,
#          'dill weed': 759,
#          'half-and-half cream': 758,
#          'provolone cheese': 755,
#          'lemon peel': 755,
#          'sage': 751,
#          'goat cheese': 751,
#          'nonfat milk': 751,
#          'poultry seasoning': 745,
#          'ground turmeric': 741,
#          'whole kernel corn': 738,
#          'rice wine vinegar': 736,
#          'quick-cooking oats': 727,
#          'unsweetened applesauce': 726,
#          'brandy': 726,
#          'american cheese': 725,
#          'light soy sauce': 724,
#          'black peppercorns': 723,
#          'yellow onions': 718,
#          'large shrimp': 718,
#          'oranges': 718,
#          'unbleached all-purpose flour': 715,
#          'sunflower seeds': 714,
#          'golden raisin': 713,
#          'prepared horseradish': 710,
#          'tomato puree': 709,
#          'egg noodles': 709,
#          'liquid smoke': 708,
#          'hamburger buns': 708,
#          'pinto beans': 702,
#          'granny smith apples': 702,
#          'cajun seasoning': 699,
#          'dill': 699,
#          'vanilla ice cream': 698,
#          'crabmeat': 698,
#          'mustard seeds': 698,
#          'penne pasta': 695,
#          'nonstick cooking spray': 691,
#          'fresh blueberries': 690,
#          'artichoke hearts': 688,
#          'yellow bell pepper': 687,
#          'fresh basil leaves': 678,
#          'pepperoni': 677,
#          'prosciutto': 675,
#          'cornflour': 675,
#          'corn syrup': 671,
#          'sweet red pepper': 668,
#          'bell peppers': 667,
#          'cloves': 665,
#          'parmigiano-reggiano cheese': 665,
#          'couscous': 664,
#          'sauerkraut': 663,
#          'pumpkin pie spice': 662,
#          'celery rib': 662,
#          'pecan halves': 661,
#          'dried onion flakes': 660,
#          'brown rice': 658,
#          'lemon rind': 657,
#          'fresh coriander': 656,
#          'tuna': 654,
#          'shredded cheddar cheese': 653,
#          'taco seasoning mix': 651,
#          'linguine': 649,
#          'catsup': 649,
#          'tomato juice': 645,
#          'panko breadcrumbs': 644,
#          'long grain rice': 644,
#          'white chocolate chips': 641,
#          'chicken thighs': 640,
#          'rind of': 639,
#          'pineapple juice': 639,
#          'romano cheese': 637,
#          'lime zest': 637,
#          'medium shrimp': 636,
#          'bittersweet chocolate': 635,
#          'chicken breast': 632,
#          'spring onions': 632,
#          'kalamata olive': 631,
#          'pesto sauce': 631,
#          'fresh gingerroot': 631,
#          'dried apricot': 631,
#          'green bell peppers': 630,
#          'seasoning': 630,
#          'caraway seed': 628,
#          'onion soup mix': 626,
#          'green olives': 625,
#          'light cream': 625,
#          'peas': 624,
#          'egg substitute': 623,
#          'pineapple': 621,
#          'dry yeast': 620,
#          'chicken wings': 619,
#          'minced garlic cloves': 619,
#          'mustard powder': 617,
#          'pumpkin puree': 617,
#          'oyster sauce': 616,
#          'garbanzo beans': 615,
#          'lemon pepper': 615,
#          'button mushrooms': 612,
#          'yogurt': 611,
#          'juice and zest of': 611,
#          'mashed potatoes': 611,
#          'parsley flakes': 608,
#          'splenda granular': 607,
#          'beef': 606,
#          'yellow squash': 606,
#          'fresh parsley leaves': 606,
#          'fresh orange juice': 605,
#          'old bay seasoning': 604,
#          'green cabbage': 604,
#          'refried beans': 599,
#          'diced green chilies': 594,
#          'corn flakes': 592,
#          'white rice': 591,
#          'cannellini beans': 591,
#          'orange marmalade': 589,
#          'hamburger': 589,
#          'italian sausage': 584,
#          'cashews': 582,
#          'boneless skinless chicken thighs': 581,
#          'vegetable shortening': 580,
#          'eggplants': 580,
#          'red kidney beans': 579,
#          'grape tomatoes': 578,
#          'fresh green beans': 577,
#          'white flour': 575,
#          'bean sprouts': 574,
#          'sweet potato': 574,
#          'mandarin oranges': 573,
#          'basmati rice': 572,
#          'old fashioned oats': 570,
#          'yellow mustard': 568,
#          'fennel seed': 568,
#          'mango': 565,
#          'light sour cream': 564,
#          'fresh sage': 560,
#          'marjoram': 560,
#          'cranberries': 556,
#          'soymilk': 554,
#          'table salt': 554,
#          'gruyere cheese': 549,
#          'horseradish': 548,
#          'low-fat milk': 545,
#          'tomato soup': 543,
#          'shredded coconut': 543,
#          'pizza sauce': 543,
#          'sun-dried tomato': 543,
#          'light mayonnaise': 542,
#          'orzo pasta': 541,
#          'fresh cranberries': 537,
#          'pears': 534,
#          'monterey jack pepper cheese': 531,
#          'baby spinach leaves': 531,
#          'canned pumpkin': 530,
#          'lasagna noodles': 529,
#          'unsweetened chocolate': 527,
#          'iceberg lettuce': 526,
#          'red peppers': 526,
#          'tahini': 522,
#          'fresh cilantro leaves': 521,
#          'dried marjoram': 521,
#          'italian dressing': 520,
#          'rum': 518,
#          'wheat germ': 515,
#          'whole cloves': 515,
#          'self-rising flour': 514,
#          'cooked bacon': 514,
#          'sweet paprika': 514,
#          'roasted red peppers': 510,
#          'macaroni': 510,
#          'fresh mint leaves': 509,
#          'salad oil': 508,
#          'whipped topping': 507,
#          'snow peas': 506,
#          'dark chocolate': 506,
#          'unflavored gelatin': 505,
#          'milk chocolate chips': 504,
#          'roasted red pepper': 500,
#          'whole wheat bread': 500,
#          'dried sage': 499,
#          'ground chuck': 498,
#          'firm tofu': 497,
#          'italian seasoned breadcrumbs': 496,
#          'white chocolate': 495,
#          'ranch dressing': 495,
#          'whole tomatoes': 493,
#          'dried parsley flakes': 487,
#          'fresh flat-leaf parsley': 487,
#          'dried tarragon': 487,
#          'reduced-sodium chicken broth': 487,
#          'quick oats': 486,
#          'red food coloring': 485,
#          'pineapple chunks': 484,
#          'lemon wedge': 481,
#          'chicken bouillon cubes': 479,
#          'apple cider': 479,
#          '2% low-fat milk': 479,
#          'teriyaki sauce': 478,
#          'unbleached flour': 478,
#          'cinnamon sticks': 477,
#          'miracle whip': 477,
#          'marshmallows': 476,
#          'raspberries': 476,
#          'lentils': 475,
#          'unsweetened cocoa': 474,
#          'chopped tomato': 473,
#          'dry onion soup mix': 473,
#          'mint': 472,
#          'marinara sauce': 471,
#          'fresh tarragon': 470,
#          'dark rum': 466,
#          'asiago cheese': 466,
#          'butterscotch chips': 465,
#          'greek yogurt': 465,
#          'cherry pie filling': 464,
#          'smoked paprika': 464,
#          'sun-dried tomatoes': 463,
#          'frozen mixed vegetables': 459,
#          'cream of celery soup': 458,
#          'angel hair pasta': 457,
#          'poppy seed': 456,
#          'macadamia nuts': 456,
#          'sweetened flaked coconut': 456,
#          'toasted sesame seeds': 454,
#          'self raising flour': 454,
#          'diced onion': 453,
#          'pasta sauce': 453,
#          'salt & fresh ground pepper': 451,
#          'cilantro leaf': 451,
#          'vanilla essence': 449,
#          'quinoa': 449,
#          'chicken pieces': 447,
#          'instant vanilla pudding': 446,
#          'bisquick': 444,
#          'vegetable oil cooking spray': 444,
#          'pure maple syrup': 442,
#          'tarragon': 439,
#          'part-skim mozzarella cheese': 439,
#          'onion salt': 438,
#          'turmeric powder': 438,
#          'lemongrass': 437,
#          'cooked chicken breasts': 435,
#          'water chestnuts': 434,
#          'corn oil': 433,
#          'lettuce leaves': 433,
#          'ground mustard': 432,
#          'red chili powder': 432,
#          'sausage': 431,
#          'bourbon': 431,
#          'hazelnuts': 431,
#          'cooked brown rice': 430,
#          'dried dill': 427,
#          'yukon gold potatoes': 426,
#          'low-fat sour cream': 425,
#          'red cabbage': 424,
#          'refrigerated crescent dinner rolls': 422,
#          'new potatoes': 421,
#          'vegetables': 418,
#          'arborio rice': 416,
#          'rhubarb': 415,
#          'chili': 413,
#          'fresh parmesan cheese': 413,
#          'noodles': 413,
#          'orange peel': 413,
#          'mangoes': 413,
#          'salmon': 412,
#          'portabella mushrooms': 412,
#          '1% low-fat milk': 412,
#          'creme fraiche': 412,
#          'condensed cream of mushroom soup': 411,
#          'ground cayenne pepper': 411,
#          'creamed corn': 411,
#          'chicken breast halves': 411,
#          'fresh breadcrumb': 410,
#          'italian parsley': 410,
#          'chorizo sausage': 410,
#          'fresh italian parsley': 409,
#          'reduced sodium soy sauce': 408,
#          'plain breadcrumbs': 408,
#          'self-raising flour': 407,
#          'dark sesame oil': 407,
#          'toasted sesame oil': 405,
#          'italian bread': 405,
#          'cumin powder': 405,
#          'smoked sausage': 403,
#          'fresh tomatoes': 403,
#          'apricot preserves': 399,
#          'ice water': 397,
#          'lemon extract': 397,
#          'rice flour': 396,
#          'ground chicken': 396,
#          'chocolate': 395,
#          'nonfat sour cream': 395,
#          'smoked salmon': 391,
#          'bacon bits': 391,
#          'saffron': 389,
#          'creole seasoning': 388,
#          'low-fat cheddar cheese': 387,
#          'dried thyme leaves': 382,
#          'fresh lemon rind': 382,
#          'kalamata olives': 382,
#          'miniature marshmallows': 381,
#          'cooked turkey': 381,
#          'light cream cheese': 380,
#          'salted butter': 378,
#          'diced tomato': 378,
#          'pistachios': 378,
#          'mexican blend cheese': 377,
#          'fresh asparagus': 377,
#          'coriander leaves': 377,
#          'pie crusts': 376,
#          'rice krispies': 376,
#          'cream-style corn': 376,
#          'mini marshmallows': 375,
#          'beef bouillon cubes': 372,
#          'poppy seeds': 372,
#          'gorgonzola': 370,
#          'broccoli floret': 369,
#          'powdered milk': 369,
#          'seasoned bread crumbs': 368,
#          'yellow pepper': 366,
#          'boneless pork chops': 365,
#          'cardamom': 365,
#          'kielbasa': 365,
#          'tilapia fillets': 365,
#          'mirin': 364,
#          'dried oregano leaves': 364,
#          'sweet onions': 363,
#          'pizza dough': 363,
#          'granny smith apple': 363,
#          'vanilla instant pudding mix': 362,
#          'frozen whipped topping': 362,
#          'red chilies': 362,
#          'fat free cream cheese': 361,
#          'arugula': 361,
#          'fresh garlic cloves': 360,
#          'spinach leaves': 360,
#          'lettuce leaf': 360,
#          'chipotle chile in adobo': 359,
#          'coriander powder': 358,
#          'sunflower oil': 358,
#          'pancetta': 358,
#          'tortillas': 357,
#          'dried dill weed': 356,
#          'beets': 356,
#          'peppercorns': 356,
#          'olive': 356,
#          'green chili': 354,
#          'ghee': 353,
#          'long-grain rice': 352,
#          'kale': 352,
#          'brie cheese': 351,
#          'white cake mix': 351,
#          'pork sausage': 351,
#          'pork': 348,
#          'chipotle chiles in adobo': 348,
#          'low-fat mayonnaise': 348,
#          'tart apples': 348,
#          'sweet pickle relish': 347,
#          'extra lean ground beef': 347,
#          'dried italian seasoning': 346,
#          'currants': 345,
#          'mascarpone cheese': 345,
#          'baguette': 343,
#          'feta': 342,
#          'ground almonds': 342,
#          'condensed cream of chicken soup': 341,
#          'white onions': 341,
#          'fettuccine': 341,
#          'coriander seed': 339,
#          'vidalia onion': 339,
#          'parsnips': 339,
#          'pearl barley': 336,
#          'bow tie pasta': 334,
#          'wide egg noodles': 333,
#          'soft breadcrumbs': 332,
#          'colby-monterey jack cheese': 332,
#          'maraschino cherries': 331,
#          'italian salad dressing': 330,
#          'fat free sour cream': 330,
#          'alfredo sauce': 330,
#          'enchilada sauce': 330,
#          'puff pastry': 329,
#          'sherry wine vinegar': 328,
#          'prawns': 328,
#          'turkey': 327,
#          'asparagus spears': 327,
#          'lard': 327,
#          'cooked white rice': 326,
#          'bisquick baking mix': 326,
#          'fresh thyme leave': 326,
#          'fresh pineapple': 325,
#          'sliced water chestnuts': 324,
#          'pita bread': 322,
#          'lime wedge': 322,
#          'dried apricots': 321,
#          'penne': 321,
#          'graham crackers': 320,
#          'oregano leaves': 318,
#          'rice wine': 317,
#          'maraschino cherry': 317,
#          'pie crust': 317,
#          'whole chickens': 317,
#          'mint leaf': 317,
#          'marinated artichoke hearts': 316,
#          'plain low-fat yogurt': 315,
#          'low fat cottage cheese': 315,
#          'flank steaks': 315,
#          'tomatoes and green chilies': 313,
#          'oat bran': 313,
#          'oreo cookies': 312,
#          'deli ham': 312,
#          'whole wheat pastry flour': 312,
#          'dried cherries': 312,
#          'white beans': 310,
#          'sourdough bread': 310,
#          'wonton wrappers': 309,
#          'red chile': 306,
#          'chicken bouillon cube': 306,
#          'dijon-style mustard': 306,
#          'ground lamb': 305,
#          'guacamole': 304,
#          'instant yeast': 303,
#          'crystallized ginger': 303,
#          'beef stew meat': 299,
#          'saltine crackers': 299,
#          'fresh tomato': 298,
#          'chili flakes': 298,
#          'olive oil flavored cooking spray': 297,
#          'great northern beans': 297,
#          'fresh mozzarella cheese': 297,
#          'golden syrup': 297,
#          'wild rice': 297,
#          'english cucumber': 296,
#          'wine vinegar': 296,
#          'minced garlic clove': 296,
#          'radishes': 295,
#          'smooth peanut butter': 294,
#          'hot dogs': 294,
#          'ranch dressing mix': 294,
#          'cumin seeds': 294,
#          'whole berry cranberry sauce': 292,
#          'rotini pasta': 292,
#          'sweet chili sauce': 292,
#          'spring onion': 292,
#          'chocolate syrup': 289,
#          'baking cocoa': 289,
#          'fat-free mayonnaise': 289,
#          'chunky salsa': 288,
#          'vanilla bean': 288,
#          'canned tomatoes': 288,
#          'saffron thread': 287,
#          'green food coloring': 286,
#          'tuna in water': 286,
#          'sea scallops': 286,
#          'frozen chopped broccoli': 285,
#          'condensed tomato soup': 284,
#          'soya sauce': 284,
#          'mixed salad greens': 284,
#          'low-fat buttermilk': 283,
#          'instant chocolate pudding mix': 283,
#          'tequila': 283,
#          'extra-sharp cheddar cheese': 283,
#          'frozen corn kernels': 283,
#          'apricot jam': 283,
#          'black-eyed peas': 282,
#          'diced tomatoes with juice': 282,
#          'instant coffee': 281,
#          'part-skim ricotta cheese': 280,
#          'tamari': 280,
#          'red capsicum': 280,
#          'fish fillets': 279,
#          'green peas': 277,
#          'coleslaw mix': 277,
#          'double cream': 277,
#          'bok choy': 277,
#          'corn kernels': 276,
#          'salted peanuts': 275,
#          'xanthan gum': 275,
#          'dark soy sauce': 275,
#          'thyme leaves': 275,
#          'nonfat dry milk powder': 274,
#          'spicy brown mustard': 274,
#          'chicken bouillon': 273,
#          'desiccated coconut': 272,
#          'fresh broccoli': 272,
#          'chuck roast': 272,
#          'pineapple tidbits': 271,
#          'condensed milk': 271,
#          'instant rice': 271,
#          'plum tomato': 271,
#          'frozen puff pastry': 270,
#          'superfine sugar': 270,
#          'olives': 269,
#          'pumpkin seeds': 268,
#          'lump crabmeat': 268,
#          'roasting chickens': 268,
#          'picante sauce': 267,
#          'mixed vegetables': 267,
#          'sliced ripe olives': 266,
#          'bicarbonate of soda': 266,
#          'anchovy fillets': 265,
#          'summer squash': 265,
#          'kahlua': 264,
#          'ritz crackers': 264,
#          'raw shrimp': 264,
#          'dried breadcrumbs': 263,
#          'crunchy peanut butter': 263,
#          'coconut oil': 263,
#          'extra firm tofu': 263,
#          'reduced-fat cream cheese': 262,
#          'grand marnier': 262,
#          'rigatoni pasta': 262,
#          'food coloring': 262,
#          'barley': 261,
#          'skinless chicken breasts': 261,
#          'fettuccine pasta': 260,
#          'phyllo dough': 260,
#          'roma tomato': 260,
#          'beef brisket': 260,
#          'fresh thyme leaves': 260,
#          'ground flax seeds': 259,
#          'dried basil leaves': 258,
#          'fresh breadcrumbs': 258,
#          'stewing beef': 257,
#          'frozen orange juice concentrate': 257,
#          'pork and beans': 256,
#          'chinese five spice powder': 256,
#          'plain nonfat yogurt': 255,
#          'reduced-fat sour cream': 255,
#          'five-spice powder': 255,
#          'chili paste': 255,
#          'long-grain white rice': 255,
#          'rotel tomatoes': 254,
#          'french-fried onions': 254,
#          'red chili pepper': 253,
#          'pitted dates': 253,
#          'cauliflower florets': 253,
#          'sun-dried tomato packed in oil': 253,
#          'mini chocolate chip': 252,
#          'baked beans': 252,
#          'fontina cheese': 252,
#          'cooked shrimp': 252,
#          'herbes de provence': 252,
#          'light olive oil': 251,
#          'lean ground turkey': 250,
#          'brewed coffee': 250,
#          'frozen broccoli': 249,
#          'crisco': 249,
#          'sugar substitute': 248,
#          "devil's food cake mix": 247,
#          'round steaks': 247,
#          'chicken drumsticks': 247,
#          'button mushroom': 246,
#          'tofu': 246,
#          'english muffins': 246,
#          'raspberry jam': 245,
#          'berries': 244,
#          'mild cheddar cheese': 244,
#          'low-fat cream cheese': 244,
#          'rolls': 243,
#          'crouton': 242,
#          'sweet corn': 242,
#          'honey mustard': 242,
#          'ground sage': 240,
#          'dried onion': 240,
#          'pitted black olives': 240,
#          'plain fat-free yogurt': 239,
#          'shiitake mushrooms': 239,
#          'vodka': 238,
#          'fine dry breadcrumb': 238,
#          'brussels sprouts': 237,
#          'pimientos': 236,
#          'scallops': 236,
#          'acorn squash': 236,
#          'cantaloupe': 236,
#          'sake': 235,
#          'chili-garlic sauce': 234,
#          'corn kernel': 234,
#          'chilies': 234,
#          'whole chicken': 234,
#          'liquid honey': 234,
#          'spanish onion': 234,
#          'chunky peanut butter': 234,
#          'fresh raspberry': 234,
#          'prepared yellow mustard': 233,
#          'chocolate cake mix': 233,
#          'flax seed meal': 233,
#          'crescent rolls': 233,
#          'napa cabbage': 233,
#          'vanilla wafers': 232,
#          'fresh spinach leaves': 232,
#          'pear': 232,
#          'corned beef': 232,
#          'salami': 232,
#          'chili beans': 232,
#          'light coconut milk': 232,
#          'potato starch': 232,
#          'potato chips': 232,
#          'adobo sauce': 231,
#          'ziti pasta': 231,
#          'reduced-sodium fat-free chicken broth': 231,
#          'turkey breast': 231,
#          'cremini mushrooms': 231,
#          'pecorino romano cheese': 231,
#          'cardamom pods': 230,
#          'cognac': 230,
#          'green chili peppers': 230,
#          'walnut pieces': 230,
#          'stock': 229,
#          'instant coffee granules': 229,
#          'radish': 229,
#          'nutritional yeast': 228,
#          'caramels': 228,
#          'chili pepper': 228,
#          'aluminum foil': 227,
#          'bread machine yeast': 227,
#          'whole grain mustard': 227,
#          'dry roasted peanuts': 227,
#          'ginger powder': 227,
#          'star anise': 226,
#          'smoked ham': 226,
#          ...})
